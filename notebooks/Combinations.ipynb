# %% [markdown]
# # Computing the Optimal First Words
#
# We are trying to find some candidate first words based on our heuristics: smallest worst partition and smallest mean partition.

# %%
# we have to use some previous code
import sys
sys.path.append('..')

# %%
# make sure we reload the code
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# helpful utilities
from parse_data import read_parsed_words, DEFAULT_PARSED_WORDS_FILE, read_all_answers
from play import UNSAFE_eval_guess, eval_guess

# %%
words = read_parsed_words()
print(f'Loaded {len(words)} words')
# Out:
# Loaded 12972 words

# %%
answers = read_all_answers()
print(f'Loaded {len(answers)} answers')
# Out:
# Loaded 2315 answers

# %%
from tqdm import tqdm
import itertools

# %% [markdown]
# ## Using the Possibilities Matrix

# %%
from possibilities_table import TABLE_PATH_ASYMMETRIC

# %% [markdown]
# Because the possibilities matrix has the words in a different order, load that from the disk

# %%
import pickle
with open('../data-parsed/possibilities-keys-asymmetric.pickle', 'rb') as fp:
    guess_words, answer_words = pickle.load(fp)

# %%
num_combos = len(guess_words) * len(answer_words)
print(f'Matrix size = {num_combos:,}')
# Out:
# Matrix size = 30,030,180

# %% [markdown]
# Load the pre-computed matrix from disk

# %%
import numpy as np
table = np.load('../data-parsed/possibilities-table-asymmetric-base-3.npy')
table.shape
# Out:
# (12972, 2315)

# %%
table.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# ## Shrinking the Possibilities Matrix

# %%
import pandas as pd

# %%
table = np.load(TABLE_PATH)

# %%
table.shape
# Out:
# (12972, 12972)

# %%
table.dtype
# Out:
# dtype('uint8')

# %%
df = pd.DataFrame(table, index=guess_words, columns=answer_words)
df
# Out:
#        aback  abase  abate  abbey  abbot  abhor  abide  abled  abode  abort  \
# aback    242     26     26     17     17     17     17     17     17     17
# abase     26    242    188     98     17     17    179     98    179     17
# abate     26    188    242     98     44     17    179     98    179     44
# abbey     17     44     44    242     26     17     44     71     44     17
# abbot     17     17     98     26    242     71     17     17     44    206
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# zuzim      0      0      0      0      0      0     27      0      0      0
# zygal     27     27     27     30     27     27     27    108     27     27
# zygon      0      0      0      3     54     54      0      0     27     27
# zymes      0    108     27     57      0      0     27     54     27      0
# zymic     81      0      0      3      0      0     27      0      0      0
#
#        ...  wryly  yacht  yearn  yeast  yield  young  youth  zebra  zesty  \
# aback  ...      0     37     19     19      0      0      0     13      0
# abase  ...      0     10    100    154     81      0      0     94    108
# abate  ...      0     37    100    127     81      0     54     94    135
# abbey  ...    162     82    109    109    108     81     81     49    189
# abbot  ...      0    163      1    163      0     27    108     22     81
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# zuzim  ...      0      0      0      0     27      3      3     11     11
# zygal  ...     84     30     30     30     84     12      3     29      5
# zygon  ...      3      3    165      3      3    120     30      2      5
# zymes  ...      3      3     30    111     30      3      3     29    113
# zymic  ...      3     84      3      3     30      3      3      2      5
#
#        zonal
# aback     10
# abase     10
# abate     10
# abbey      1
# abbot     28
# ...      ...
# zuzim     11
# zygal    218
# zygon    110
# zymes      2
# zymic      2
#
# [12972 rows x 2315 columns]

# %%
# save to parquet-gzip to save space
df.to_parquet(
    '../data-parsed/possibilities-table-asymmetric-base-3.parquet.gzip',
    engine='pyarrow',
    compression='gzip',
    index=True,
)

# %% [markdown]
# ## Evaluating the First Word Candidates

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_parquet('../data-parsed/possibilities-table-asymmetric-base-3.parquet.gzip')
df
# Out:
#        aback  abase  abate  abbey  abbot  abhor  abide  abled  abode  abort  \
# aback    242     26     26     17     17     17     17     17     17     17
# abase     26    242    188     98     17     17    179     98    179     17
# abate     26    188    242     98     44     17    179     98    179     44
# abbey     17     44     44    242     26     17     44     71     44     17
# abbot     17     17     98     26    242     71     17     17     44    206
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# zuzim      0      0      0      0      0      0     27      0      0      0
# zygal     27     27     27     30     27     27     27    108     27     27
# zygon      0      0      0      3     54     54      0      0     27     27
# zymes      0    108     27     57      0      0     27     54     27      0
# zymic     81      0      0      3      0      0     27      0      0      0
#
#        ...  wryly  yacht  yearn  yeast  yield  young  youth  zebra  zesty  \
# aback  ...      0     37     19     19      0      0      0     13      0
# abase  ...      0     10    100    154     81      0      0     94    108
# abate  ...      0     37    100    127     81      0     54     94    135
# abbey  ...    162     82    109    109    108     81     81     49    189
# abbot  ...      0    163      1    163      0     27    108     22     81
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# zuzim  ...      0      0      0      0     27      3      3     11     11
# zygal  ...     84     30     30     30     84     12      3     29      5
# zygon  ...      3      3    165      3      3    120     30      2      5
# zymes  ...      3      3     30    111     30      3      3     29    113
# zymic  ...      3     84      3      3     30      3      3      2      5
#
#        zonal
# aback     10
# abase     10
# abate     10
# abbey      1
# abbot     28
# ...      ...
# zuzim     11
# zygal    218
# zygon    110
# zymes      2
# zymic      2
#
# [12972 rows x 2315 columns]

# %% [markdown]
# ### Mean Partition

# %%
def get_mean_partition(row: np.ndarray) -> float:
    x = row.value_counts().to_dict()
    arr = np.array([v for v in x.values()])
    return np.mean(arr)

mean_part_df = df.apply(get_mean_partition, axis=1)

# %%
mean_part_df = pd.DataFrame(mean_part_df, columns=['mean_partition'])
mean_part_df
# Out:
#        mean_partition
# aback       48.229167
# abase       35.075758
# abate       31.712329
# abbey       39.237288
# abbot       34.044118
# ...               ...
# zuzim       72.343750
# zygal       37.338710
# zygon       38.583333
# zymes       47.244898
# zymic       46.300000
#
# [12972 rows x 1 columns]

# %%
mean_part_df.sort_values('mean_partition').head(15)
# Out:
#        mean_partition
# trace       15.433333
# crate       15.641892
# salet       15.641892
# slate       15.748299
# reast       15.748299
# carte       15.856164
# parse       15.856164
# peart       15.965517
# caret       15.965517
# carle       16.076389
# crane       16.302817
# earst       16.302817
# stale       16.302817
# reist       16.418440
# heart       16.418440

# %%
mean_part_df.loc['adieu']
# Out:
# mean_partition    28.9375
# Name: adieu, dtype: float64

# %%
mean_part_df.loc['adieu'] / mean_part_df.loc['trace']
# Out:
# mean_partition    1.875
# dtype: float64

# %%
mean_part_df.idxmax()
# Out:
# mean_partition    qajaq
# dtype: object

# %% [markdown]
# ### Worst Partitions

# %%
def get_worst_partition(row) -> int:
    x = row.value_counts().to_dict()
    m = max(x.values())
    return m

# apply function to each row
part_df = df.apply(get_worst_partition, axis=1)

# %%
part_df = pd.DataFrame(part_df, columns=['worst_partition'])
part_df
# Out:
#        worst_partition
# aback              925
# abase              423
# abate              419
# abbey              442
# abbot              543
# ...                ...
# zuzim             1092
# zygal              717
# zygon              874
# zymes              544
# zymic              873
#
# [12972 rows x 1 columns]

# %%
part_df.sort_values('worst_partition').head(15)
# Out:
#        worst_partition
# arise              168
# reais              168
# aesir              168
# serai              168
# raise              168
# aiery              171
# ayrie              171
# raile              173
# ariel              173
# aloes              174
# realo              176
# stoae              177
# alone              182
# anole              182
# aeros              183

# %%
part_df.worst_partition.min()
# Out:
# 168

# %%
part_df[part_df.worst_partition == 697]
# Out:
#        worst_partition
# serai              697

# %%
part_df.loc['adieu']
# Out:
# worst_partition    284
# Name: adieu, dtype: int64

# %%
part_df.loc['adieu'] / part_df.loc['arise']
# Out:
# worst_partition    1.690476
# dtype: float64

# %%
part_df.loc['adieu'] / 697
# Out:
# worst_partition    2.451937
# Name: adieu, dtype: float64

# %%
part_df.loc['arise'] / 697
# Out:
# worst_partition    1.265423
# Name: arise, dtype: float64

# %%
part_df.loc['tares']
# Out:
# worst_partition    858
# Name: tares, dtype: int64

# %%
part_df.loc['aesir']
# Out:
# worst_partition    868
# Name: aesir, dtype: int64

# %%
part_df.loc['arise']
# Out:
# worst_partition    882
# Name: arise, dtype: int64

# %%
part_df.idxmax()
# Out:
# worst_partition    gyppy
# dtype: object

# %% [markdown]
# ## Solver Evaluation
#
# After running our solver over the past answers, let's see how we did

# %%
import json
import pandas as pd

# %%
def load_data(word, strategy, n) -> pd.DataFrame:
    d = {}
    with open(f'../data-parsed/solver-eval/solver-eval-strat-{strategy}-past-answers-{n}-{word}.json', 'r') as fp:
        d = json.load(fp)

    rows = []
    for answer, v in d['per_word_results'].items():
        rows.append({
            'answer': answer,
            'num_guesses': v['num_guesses'],
            'is_solved': v['is_solved']
        })

    solver_df = pd.DataFrame(rows)
    return solver_df

# %%
def print_stats(solver_df: pd.DataFrame):
    print('# solved successfully', solver_df.is_solved.sum())
    mean_guesses = solver_df[solver_df.is_solved].num_guesses.mean()
    print(f'avg # guesses per puzzle (solved) {mean_guesses:.2f}')
    unsolved = solver_df[~solver_df.is_solved]
    print('unsolved:')
    display(unsolved[['answer']])

# %% [markdown]
# ### serai - worst partition

# %%
solver_df = load_data('serai', 'worst_partition', n=219)

# %%
solver_df
# Out:
#     answer  num_guesses  is_solved
# 0    ABACK            4       True
# 1    ABASE            4       True
# 2    ABATE            4       True
# 3    ABBEY            4       True
# 4    ABYSS            4       True
# ..     ...          ...        ...
# 214  WINCE            4       True
# 215  WOOER            5       True
# 216  WORLD            3       True
# 217  WROTE            6      False
# 218  YEARN            4       True
#
# [219 rows x 3 columns]

# %%
print_stats(solver_df)
# Out:
# # solved successfully 212
# avg # guesses per puzzle (solved) 4.20
# unsolved:
#     answer  num_guesses  is_solved
# 29   BOOZY            6      False
# 51   CRAZE            6      False
# 99   GRIME            6      False
# 149  PROVE            6      False
# 188  STORE            6      False
# 189  STOUT            6      False
# 217  WROTE            6      False

# %% [markdown]
# ### tares - worst partition

# %%
solver_df = load_data('tares', 'worst_partition', n=219)
solver_df
# Out:
#     answer  num_guesses  is_solved
# 0    ABACK            4       True
# 1    ABASE            4       True
# 2    ABATE            3       True
# 3    ABBEY            4       True
# 4    ABYSS            5       True
# ..     ...          ...        ...
# 214  WINCE            5       True
# 215  WOOER            5       True
# 216  WORLD            4       True
# 217  WROTE            4       True
# 218  YEARN            4       True
#
# [219 rows x 3 columns]

# %%
print_stats(solver_df)
# Out:
# # solved successfully 213
# avg # guesses per puzzle (solved) 4.25
# unsolved:
#     answer  num_guesses  is_solved
# 29   BOOZY            6      False
# 51   CRAZE            6      False
# 93   GONER            6      False
# 120  LUSTY            6      False
# 149  PROVE            6      False
# 177  SOWER            6      False

# %% [markdown]
# ### tares - mean partition

# %%
solver_df = load_data('tares', 'mean_partition', n=219)

# %%
print_stats(solver_df)
# Out:
# # solved successfully 208
# avg # guesses per puzzle (solved) 4.02
# unsolved:
#     answer  num_guesses  is_solved
# 29   BOOZY            6      False
# 49   CRASS            6      False
# 51   CRAZE            6      False
# 75   FERRY            6      False
# 78   FIXER            6      False
# 93   GONER            6      False
# 145  POUND            6      False
# 149  PROVE            6      False
# 184  START            6      False
# 189  STOUT            6      False
# 215  WOOER            6      False

# %% [markdown]
# ### stats for everything

# %%
for word in ['serai', 'tares', 'adieu']:
    for strat in ['mean_partition', 'worst_partition']:
        print(f'word: {word}, strat: {strat}')
        solver_df = load_data(word, strat, n=219)
        print_stats(solver_df)
# Out:
# word: serai, strat: mean_partition
# # solved successfully 208
# avg # guesses per puzzle (solved) 4.20
# unsolved:
#     answer
# 29   BOOZY
# 51   CRAZE
# 75   FERRY
# 78   FIXER
# 93   GONER
# 99   GRIME
# 149  PROVE
# 150  PROXY
# 184  START
# 188  STORE
# 215  WOOER
# word: serai, strat: worst_partition
# # solved successfully 212
# avg # guesses per puzzle (solved) 4.20
# unsolved:
#     answer
# 29   BOOZY
# 51   CRAZE
# 99   GRIME
# 149  PROVE
# 188  STORE
# 189  STOUT
# 217  WROTE
# word: tares, strat: mean_partition
# # solved successfully 208
# avg # guesses per puzzle (solved) 4.02
# unsolved:
#     answer
# 29   BOOZY
# 49   CRASS
# 51   CRAZE
# 75   FERRY
# 78   FIXER
# 93   GONER
# 145  POUND
# 149  PROVE
# 184  START
# 189  STOUT
# 215  WOOER
# word: tares, strat: worst_partition
# # solved successfully 213
# avg # guesses per puzzle (solved) 4.25
# unsolved:
#     answer
# 29   BOOZY
# 51   CRAZE
# 93   GONER
# 120  LUSTY
# 149  PROVE
# 177  SOWER
# word: adieu, strat: mean_partition
# # solved successfully 204
# avg # guesses per puzzle (solved) 4.20
# unsolved:
#     answer
# 14   AWAKE
# 29   BOOZY
# 49   CRASS
# 51   CRAZE
# 78   FIXER
# 99   GRIME
# 105  HATCH
# 134  PANEL
# 145  POUND
# 149  PROVE
# 171  SISSY
# 184  START
# 185  STEED
# 189  STOUT
# 215  WOOER
# word: adieu, strat: worst_partition
# # solved successfully 204
# avg # guesses per puzzle (solved) 4.26
# unsolved:
#     answer
# 14   AWAKE
# 29   BOOZY
# 49   CRASS
# 51   CRAZE
# 83   FLOSS
# 93   GONER
# 100  GRIPE
# 119  LOOPY
# 136  PAPER
# 137  PARRY
# 145  POUND
# 149  PROVE
# 171  SISSY
# 184  START
# 189  STOUT
